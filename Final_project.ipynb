# %% [markdown]
# <a href="https://colab.research.google.com/github/mandy2324/Gen-AI/blob/main/Final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Steps
1. Open a new Jupyter notebook (in Google Colab)
2. Import pandas and seaborn

# %% [markdown]
# Import pandas and seaborn
# Upload each csv file using the code below:

# %%
import pandas as pd
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-60e405d9-1e96-4813-a9c1-8c129a5aa192" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60e405d9-1e96-4813-a9c1-8c129a5aa192">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Read the csv files with pandas

# %%
# Read the first CSV file
df1 = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")

# Read the second CSV file
df2 = pd.read_csv("Video_Games_Sales_Truncated.csv")

# %% [markdown]
# For each data set perform the following:

# %% [markdown]
# ○ Show first five records

# %%
# Display the first five records of df1
print("First five records of df1:")
print(df1.head())

# Display the first five records of df2
print("First five records of df2:")
print(df2.head())
# Out:
# First five records of df1:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %% [markdown]
# ○ Show all columns of the dataframe

# %%
# Display all columns of df1
print("Columns of df1:")
print(df1.columns)

# Display all columns of df2
print("Columns of df2:")
print(df2.columns)
# Out:
# Columns of df1:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')
# Columns of df2:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# ○ Show last 5 five *rows*

# %%
# Display the last five rows of df1
print("Last five rows of df1:")
print(df1.tail())

# Display the last five rows of df2
print("Last five rows of df2:")
print(df2.tail())
# Out:
# Last five rows of df1:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %% [markdown]
# Feed the truncated csv into ChatGPT (or Bard) as a prompt
# ○ You can copy the data into the chatbot or send it through the API

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import openai

# Set your OpenAI API key
openai.api_key = "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"

# Define the prompt with the truncated CSV data
prompt = """
Here is the truncated CSV data:
 Critic_Score  Critic_Count  User_Score  User_Count      Developer Rating
32          87.0          89.0         6.3      1454.0       Treyarch      M
33           NaN           NaN         NaN         NaN            NaN    NaN
34          83.0          21.0         5.3       922.0       Treyarch      M
35          83.0          73.0         4.8      2256.0       Treyarch      M
36          94.0         100.0         6.3      2698.0  Infinity Ward      M
...

Now, please analyze this data and provide insights on the most popular developer rating.
"""

# Generate a response from the chatbot
response = openai.Completion.create(
    engine="davinci",  # Use the appropriate engine
    prompt=prompt,
    max_tokens=100  # Adjust the length of the response as needed
)

# Print the response from the chatbot
print(response.choices[0].text.strip())
# Out:
# 7x5 -- Aug 2015
#
# After spending days here are the top 20 phrases that might be positive alices bob casper elmow elmow3 fish franzen franzen2 getting glenn glen glenn2 happily here is hover ice if over there.
#
# Team12
#
# Data link
#
#
# Seven sub-missions were provided. Each sub-mission uses the same processing engine and source data, but the number of positive and negative ratings is different.

# %% [markdown]
#  Feed the truncated csv into ChatGPT (or Bard) as a prompt

# %%
prompt = f"""
Can you provide 5 analysis and insights into the data?



Last five rows of df1:
                                Name Platform  Year_of_Release       Genre  \
16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
16715               LMA Manager 2007     X360           2006.0      Sports
16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
16717               Spirits & Spells      GBA           2003.0    Platform
16718            Winning Post 8 2016      PSV           2016.0  Simulation

          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
16715   Codemasters      0.00      0.01      0.00          0.0          0.01
16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01

       Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
16714           NaN           NaN         NaN         NaN       NaN    NaN
16715           NaN           NaN         NaN         NaN       NaN    NaN
16716           NaN           NaN         NaN         NaN       NaN    NaN
16717           NaN           NaN         NaN         NaN       NaN    NaN
16718           NaN           NaN         NaN         NaN       NaN    NaN
Last five rows of df2:
                              Name Platform  Year_of_Release         Genre  \
32         Call of Duty: Black Ops     X360           2010.0       Shooter
33             Pokemon X/Pokemon Y      3DS           2013.0  Role-Playing
34      Call of Duty: Black Ops II      PS3           2012.0       Shooter
35      Call of Duty: Black Ops II     X360           2012.0       Shooter
36  Call of Duty: Modern Warfare 2     X360           2009.0       Shooter

     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
32  Activision      9.70      3.68      0.11         1.13         14.61
33    Nintendo      5.28      4.19      4.35         0.78         14.60
34  Activision      4.99      5.73      0.65         2.42         13.79
35  Activision      8.25      4.24      0.07         1.12         13.67
36  Activision      8.52      3.59      0.08         1.28         13.47

    Critic_Score  Critic_Count  User_Score  User_Count      Developer Rating
32          87.0          89.0         6.3      1454.0       Treyarch      M
33           NaN           NaN         NaN         NaN            NaN    NaN
34          83.0          21.0         5.3       922.0       Treyarch      M
35          83.0          73.0         4.8      2256.0       Treyarch      M
36          94.0         100.0         6.3      2698.0  Infinity Ward      M
"""



# Generate a response from the chatbot
response = openai.Completion.create(
    engine="davinci",  # Use the appropriate engine
    prompt=prompt,
    max_tokens=100  # Adjust the length of the response as needed
)

# Print the response from the chatbot
print(response.choices[0].text.strip())
# Out:
# Several questions:
#
#
# You haven't shown individual entries so the black entries could represent incomplete records, or records where the publisher or platform cannot correctly be identified. It would be interesting to see each one of the black entries
#
#
# Common pattern within each platform column: entries #33 and #36 represent a game where Activision "suspiciously" dominates in either NA or EU sales. Coincidence?
#
#
# Files #3 and #17 appear fake - too many NA/EU sales. (

# %% [markdown]
# ***7. Ask ChatGPT (or Bard) for 5 insights into the data that you could visualize***

# %% [markdown]
# Of course! Here are five insights based on the provided data:
#
# Insight 1: **Release Year Distribution**
#    - The provided data includes games released up to the year 2016.
#    - Some games in both datasets have their year of release listed as 2016.
#
# Insight 2: **Platform and Genre**
#    - "Shooter" is a prominent genre in the second dataset (df2), with games like "Call of Duty: Black Ops" and "Call of Duty: Black Ops II" falling into this category.
#    - The platform "X360" (Xbox 360) appears in both datasets, suggesting that it was a popular platform during the years covered.
#
# Insight 3: **Global Sales**
#    - Games like "Call of Duty: Black Ops" and "Pokemon X/Pokemon Y" have notably high global sales figures, indicating their popularity.
#    - Some games in the first dataset (df1) have negligible global sales, as indicated by values like 0.01.
#
# Insight 4: **Critic and User Scores**
#    - "Call of Duty: Modern Warfare 2" received high critic scores (94.0) in the second dataset (df2), indicating strong critical acclaim.
#    - Some games in both datasets have missing critic and user scores, potentially indicating incomplete or unavailable data.
#
# Insight 5: **Publishers and Developers**
#    - "Activision" is a prominent publisher and "Treyarch" is a developer associated with popular games like "Call of Duty: Black Ops" and "Call of Duty: Black Ops II."
#    - "Tecmo Koei" appears as a publisher in the first dataset (df1) and "Infinity Ward" appears as a developer in the second dataset (df2).
#
# Remember, these insights are generated based on the provided data and general trends. For more specific and accurate insights, further analysis and context might be needed.

# %% [markdown]
# 8. Visualize the truncated data sent to ChatGPT in your notebook

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# Data
game_names = [
    "Samurai Warriors: Sanada Maru",
    "LMA Manager 2007",
    "Haitaka no Psychedelica",
    "Spirits & Spells",
    "Winning Post 8 2016"
]

global_sales_df1 = [0.01, 0.01, 0.01, 0.01, 0.01]
global_sales_df2 = [14.61, 14.60, 13.79, 13.67, 13.47]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting
ax.barh(game_names, global_sales_df1, color='blue', label='df1 Global Sales')
ax.barh(game_names, global_sales_df2, color='orange', label='df2 Global Sales', left=global_sales_df1)

# Labels and title
ax.set_xlabel('Global Sales')
ax.set_ylabel('Game Names')
ax.set_title('Global Sales of Last Five Games')

# Legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# 9. Perform the same visualizations using the full data set

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Replace 'df1.csv' and 'df2.csv' with the actual filenames of your datasets

# Read the first CSV file
df1 = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")

# Read the second CSV file
df2 = pd.read_csv("Video_Games_Sales_Truncated.csv")

# %%
game_names_df1 = df1['Name']
global_sales_df1 = df1['Global_Sales']

game_names_df2 = df2['Name']
global_sales_df2 = df2['Global_Sales']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your full dataset
df1 = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")

# Read the second CSV file
df2 = pd.read_csv("Video_Games_Sales_Truncated.csv")

# Extract relevant columns
game_names = data['Name']
global_sales = data['Global_Sales']

# Create the visualization
plt.figure(figsize=(10, 6))
plt.barh(game_names, global_sales, color='blue')
plt.xlabel('Global Sales')
plt.ylabel('Game Names')
plt.title('Global Sales of Games')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your full dataset
df1 = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")

# Read the second CSV file
df2 = pd.read_csv("Video_Games_Sales_Truncated.csv")

# Extract relevant columns
game_names = data['Name']
global_sales = data['Global_Sales']

# Create the visualization
plt.figure(figsize=(10, 6))
plt.barh(game_names, global_sales, color='blue')

# Adding title and labels
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game Names')
plt.title('Global Sales of Games')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-e706e7c7da0b> in <cell line: 16>()
#      14 # Create the visualization
#      15 plt.figure(figsize=(10, 6))
# ---> 16 plt.barh(game_names, global_sales, color='blue')
#      17
#      18 # Adding title and labels
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in barh(y, width, height, left, align, data, **kwargs)
#    2455         y, width, height=0.8, left=None, *, align='center',
#    2456         data=None, **kwargs):
# -> 2457     return gca().barh(
#    2458         y, width, height=height, left=left, align=align,
#    2459         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, data, **kwargs)
#    2647         """
# ...
